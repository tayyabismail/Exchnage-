# %% [markdown]
# <a href="https://colab.research.google.com/github/tayyabismail/Exchnage-/blob/main/Exchnage_rupees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import ipywidgets as widgets
from IPython.display import display

# ExchangeRate-API URL with the provided API key
api_url = "https://v6.exchangerate-api.com/v6/d10cdf4e0852ad5e6a789660/latest/USD"

# Function to get exchange rates
def get_exchange_rates(api_url):
    response = requests.get(api_url)
    data = response.json()
    if response.status_code == 200:
        return data['conversion_rates']
    else:
        print("Error fetching data from the API. Please check the API key or URL.")
        return None

# Fetch exchange rates
rates = get_exchange_rates(api_url)

# Create dropdowns for currency selection and input for amount
if rates:
    currencies = list(rates.keys())
    from_currency_dropdown = widgets.Dropdown(options=currencies, description='From Currency:')
    to_currency_dropdown = widgets.Dropdown(options=currencies, description='To Currency:')
    amount_input = widgets.FloatText(description='Amount:', value=1.0)

    # Create a button to perform conversion
    convert_button = widgets.Button(description='Convert')
    output_label = widgets.Label()

    # Function to perform conversion
    def convert_currency(b):
        from_currency = from_currency_dropdown.value
        to_currency = to_currency_dropdown.value
        amount = amount_input.value

        if from_currency and to_currency:
            # Calculate the conversion rate
            conversion_rate = rates[to_currency] / rates[from_currency]
            converted_amount = amount * conversion_rate
            # Display the converted amount
            output_label.value = f"{amount} {from_currency} is equal to {converted_amount:.2f} {to_currency}"
        else:
            output_label.value = "Please select both currencies for conversion."

    # Bind the function to the button click event
    convert_button.on_click(convert_currency)

    # Display the widgets
    display(from_currency_dropdown, to_currency_dropdown, amount_input, convert_button, output_label)
else:
    print("Could not fetch exchange rates. Please try again later.")
# Out:
# Dropdown(description='From Currency:', options=('USD', 'AED', 'AFN', 'ALL', 'AMD', 'ANG', 'AOA', 'ARS', 'AUD',…
# Dropdown(description='To Currency:', options=('USD', 'AED', 'AFN', 'ALL', 'AMD', 'ANG', 'AOA', 'ARS', 'AUD', '…
# FloatText(value=1.0, description='Amount:')
# Button(description='Convert', style=ButtonStyle())
# Label(value='')

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 85.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import requests
import streamlit as st

# ExchangeRate-API URL with the provided API key
api_url = "https://v6.exchangerate-api.com/v6/d10cdf4e0852ad5e6a789660/latest/USD"

# Function to get exchange rates
def get_exchange_rates(api_url):
    response = requests.get(api_url)
    data = response.json()
    if response.status_code == 200:
        return data['conversion_rates']
    else:
        st.error("Error fetching data from the API. Please check the API key or URL.")
        return None

# Fetch exchange rates
rates = get_exchange_rates(api_url)

# Create currency converter app
if rates:
    st.title("Currency Converter")

    # Create dropdowns for currency selection and input for amount
    currencies = list(rates.keys())
    from_currency = st.selectbox("From Currency:", currencies)
    to_currency = st.selectbox("To Currency:", currencies)
    amount = st.number_input("Amount:", min_value=0.0, value=1.0, step=0.01)

    # Perform conversion when button is clicked
    if st.button("Convert"):
        if from_currency and to_currency:
            # Calculate the conversion rate
            conversion_rate = rates[to_currency] / rates[from_currency]
            converted_amount = amount * conversion_rate
            # Display the converted amount
            st.success(f"{amount:.2f} {from_currency} is equal to {converted_amount:.2f} {to_currency}")
        else:
            st.error("Please select both currencies for conversion.")
else:
    st.error("Could not fetch exchange rates. Please try again later.")
# Out:
# 2024-10-17 07:45:11.335 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 07:45:11.640
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2024-10-17 07:45:11.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 07:45:11.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 07:45:11.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 07:45:11.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-17 07:45:11.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
